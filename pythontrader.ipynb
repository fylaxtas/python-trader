# %%
import numpy as np
import pandas as pd
#from matplotlib import pyplot as plt
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates

file_path="C:\\Users\\phylactoum\\AppData\\Roaming\\MetaQuotes\\Terminal\\63A6B241E3C151D1D62F915B872BF91B\\MQL4\\Files"
file_name="DataCollect_EURUSD_H1"
full_file_name=file_path+"\\"+file_name+".csv"
# Out:
# UsageError: Line magic function `%%js` not found.

# %%
df=pd.read_csv(full_file_name)
df['Time'] = pd.to_datetime(df['Time'])
df["Time"] = df["Time"].apply(mdates.date2num)
df.head()
ohlc= df[['Time', 'Open', 'High', 'Low','Close']].copy()

# %%
f1, ax = plt.subplots(figsize = (10,5))


# Adding labels

candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# Saving image
plt.savefig('OHLC HDFC.png')

# Saving image
plt.savefig('Simple time series plot for EURUSD.png')

# In case you dont want to save image but just displya it
plt.show()
